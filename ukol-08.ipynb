# %%
import pandas

# %%
zvirata = pandas.read_csv('adopce-zvirat.csv', sep=";")
zvirata
# Out:
#        id             nazev_cz                     nazev_en       trida_cz  \
# 0       7          Šváb syčivý  Madagascar giant cockroach      Bezobratlí
# 1       8  Pakobylka okřídlená     Pink-winged stick insect     Bezobratlí
# 2      16                Tayra                        Tayra          Savci
# 3      35        Kajmanka supí    Alligator snapping turtle          Plazi
# 4      37      Želva žlutočelá       Indochinese box turtle          Plazi
# ..    ...                  ...                          ...            ...
# 508  1417  Rosnice šalamounská                               Obojživelníci
# 509  1418       Létavka obecná                               Obojživelníci
# 510  1419          Bažant paví                                       Ptáci
# 511  1420  Sojkovec rezavouchý                                       Ptáci
# 512  1421   Kachnice kaštanová                                       Ptáci
#
#      cena  k_prohlidce
# 0    1000            1
# ...

# %%
zvirata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           513 non-null    int64
#  1   nazev_cz     513 non-null    object
#  2   nazev_en     513 non-null    object
#  3   trida_cz     513 non-null    object
#  4   cena         513 non-null    int64
#  5   k_prohlidce  513 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 24.2+ KB

# %%
zvirata.shape
# Out:
# (513, 6)

# %%
zvirata.iloc[34]
# Out:
# id                     99
# nazev_cz        Ibis bílý
# nazev_en       White ibis
# trida_cz            Ptáci
# cena                 3000
# k_prohlidce             1
# Name: 34, dtype: object

# %%
zvirata[["nazev_cz","nazev_en"]].iloc[34]
# Out:
# nazev_cz     Ibis bílý
# nazev_en    White ibis
# Name: 34, dtype: object

# %%
zvirata.sort_values("cena").tail(30)
# Out:
#        id                                   nazev_cz  \
# 413  1278                         Pelikán skvrnozobý
# 125   373                            Kůň Převalského
# 26     88                           Pelikán kadeřavý
# 25     87                               Pelikán bílý
# 22     84                            Kasuár přílbový
# 458  1351                          Mravenečník velký
# 467  1365                             Gibon stříbrný
# 144   412                                      Bizon
# 433  1312                             Levhart jávský
# 347  1153                            Tapír čabrakový
# 145   413                                       Zubr
# 199   641                         Tapír jihoamerický
# 117   338                        Lachtan jihoafrický
# 130   387                          Velbloud dvouhrbý
# 374  1193                             Leguán modravý
# 112   331                          Levhart mandžuský
# 449  1335                            Velemlok čínský
# ...

# %%
zvirata[zvirata["cena"] == 50000]
# Out:
#       id                                   nazev_cz                nazev_en  \
# 113  334                            Tygr ussurijský          Siberian tiger
# 114  335                            Tygr sumaterský          Sumatran tiger
# 128  381                               Slon indický          Asian elephant
# 129  385                          Hroch obojživelný            Hippopotamus
# 135  396  Žirafa severní núbijská (= Rothschildova)  Rothschild's giraffe
# 272  897                              Tygr malajský           Malayan tiger
#
#     trida_cz   cena  k_prohlidce
# 113    Savci  50000            1
# 114    Savci  50000            1
# 128    Savci  50000            1
# 129    Savci  50000            1
# 135    Savci  50000            1
# 272    Savci  50000            1

# %%
zvirata.sort_values("nazev_cz").tail(1)
# Out:
#        id     nazev_cz                nazev_en trida_cz  cena  k_prohlidce
# 371  1190  Žluva hajní  Eurasian golden oriole    Ptáci  1000            1

# %%
zvirata.sort_values("nazev_en").tail(1)
# Out:
#       id             nazev_cz                 nazev_en trida_cz  cena  \
# 161  491  Frankolín žlutokrký  Yellow-necked francolin    Ptáci  1000
#
#      k_prohlidce
# 161            1

# %%
prumcena = zvirata["cena"]
prumcena.mean()
# Out:
# 3309.941520467836

# %%
trida_vyber = zvirata[zvirata["trida_cz"] == "Ptáci"]
trida_vyber.count()
# Out:
# id             237
# nazev_cz       237
# nazev_en       237
# trida_cz       237
# cena           237
# k_prohlidce    237
# dtype: int64

# %%
zvirata[zvirata["trida_cz"] == "Savci"]
# Out:
#        id             nazev_cz                nazev_en trida_cz  cena  \
# 2      16                Tayra                   Tayra    Savci  5000
# 93    269    Ježura australská    Short-beaked echidna    Savci  5000
# 94    271          Klokan rudý            Red kangaroo    Savci  7000
# 95    272     Bodlín Telfairův  Lesser hedgehog tenrec    Savci  2000
# 96    277           Lemur kata       Ring-tailed lemur    Savci  5000
# ..    ...                  ...                     ...      ...   ...
# 492  1397      Pekari Wagnerův       Catagonus wagneri    Savci  2000
# 493  1398  Dikobraz palawanský                            Savci  2000
# 495  1401         Daman stepní                            Savci  2000
# 496  1404        Dikdik Kirkův                            Savci  3000
# 497  1405       Nosál bělohubý                            Savci  5000
#
#      k_prohlidce
# 2              1
# 93             1
# 94             1
# 95             1
# 96             1
# ...
